# %%
import requests
import json
import getpass
from urllib.parse import quote

# %%
s = requests.session()

# %%
baseWsURL = 'https://lalu.sirsi.net/lalu_ilsws/rest'
clientID = 'DS_CLIENT'

with open('credentials.txt', 'r') as f:
    parsed_json = json.loads(f.read())
    username, password = None, None
#     username, password = parsed_json.get('user'), parsed_json.get('pass')
    if username and password:
        admin_login_data = {
            'baseWsURL': baseWsURL,
            'clientID': clientID,
            'login': username,
            'password': password,
        }
    else:
        admin_login_data = {
            'baseWsURL': baseWsURL,
            'clientID': clientID,
            'login': input('what is your Sirsi Workflow username? '),
            'password': getpass.getpass('what is your Sirsi Workflow password? '),
        }

# %%
login_endpoint = "{}/security/loginUser?clientID={}&login={}&password={}&json=True".format(
    admin_login_data['baseWsURL'],
    admin_login_data['clientID'],
    admin_login_data['login'],
    admin_login_data['password'],
)

# %%
r = s.post(login_endpoint)

# %%
login_json = json.loads(r.content)

# %%
login_json

# %%
api = {
    'standard': {
        'license': {},
        'lookupHotSites': {},
        'version': {},
        'lookupBestSellersDisplayList': {
            'bestSellerID': '',
        },
        'lookupBestSellerTitles': {
            'bestSellerID': '',
        },
        'lookupMostPopular': {
            'listType': '',
            'libraryFilter': '',
            'sourceFile': '',
            'linesToDisplay': '',
        },
        'LookupRecommendedReadingDisplayList': {
            'recommendedReadingID': '',
        },
        'lookupRecommendedReadingTitles': {
            'recommendedReadingID': '',
        },
        'lookupTitleInfo': {
            'libraryFilter': '',
            'titleID': '',
            'itemId': '',
            'includeAvailabilityInfo': '',
            'includeItemInfo': '',
            'includeCatalogingInfo': '',
            'includeOrderInfo': '',
            'includeOPACInfo': '',
            'includeBoundTogether': '',
            'includeMarcHoldings': '',
            'marcEntryFilter': '',
            'marcEntryID': '',
            'includeRelatedSearchInfo': '',
            'includeCallNumberSummary': '',
            'includeItemCategory': '',
            'includeShadowed': '',
        },
        # this is the eLibrary search, not Enterprise
        'searchCatalog': {
            'query': '',
            'term': '',
            'searchType': '',
            'operator': '',
            'exactMatch': '',
            'hitsToDisplay': '',
            'filters': '',
            'includeAvailabilityInfo': '',
        },
        'searchCatalogPaging': {
            'query': '',
            'term': '',
            'searchType': '',
            'operator': '',
            'exactMatch': '',
            'hitsToDisplay': '',
            'filters': '',
            'includeAvailabilityInfo': '',
        },
        'searchInfoDesk': {
            'infoDesk': '',
            'customInfoDesk': '',
            'hitsToDisplay': '',
            'filters': '',
            'includeAvailabilityInfo': '',
        },
        'searchInfoDeskPaging': {
            'infoDesk': '',
            'customInfoDesk': '',
            'hitsToDisplay': '',
            'filters': '',
            'includeAvailabilityInfo': '',
        },
    },
    'security': {
        'authenticateUser': {
            'login': '',
            'password': ''
            },
        'loginUser': {
            'login': '',
            'password': '',
            'workstationID': '',
            'includeUserMiscInfo': '',
        },
        'loginUserCAS': {
            'service': '',
            'ticker': '',
            'validateURL': '',
            'workstationID': '',
            'includeUserMiscInfo': '',
        },
        'loginUserResetMyPIN': {
            'resetPinToken': '',
            'workstationID': '',
            'includeUserMiscInfo': ''
        },
        'logoutUser': {},
        'lookupSessionInfo': {},
        'lookupUserInfo': {
            'userID': '',
            'includeAccountability': '',
            'includeAllowedCommands': '',
        },
        'resetMyPin': {
            'login': '',
            'emailTemplate': '',
            'resetPinUrl': '',
        } ,
    },
    'patron': {
        'activateOnlineRegisteredUser': {
            'assignedUserID': '',
            'newUserID': '',
            'newAltID': '',
            'newWebAuthID': '',
            'webAuthOverride': '',
            'pin': '',
        },
        'cancelMyHold': {
            'holdKey': ''
        },
        'changeMyAlternativeID': {
            'newAlternativeID': '',
        },
        'changeMyPIN': {
            'currentPIN': '',
            'newPIN': '',
        },
        'createMyHold': {
            'itemID': '',
            'titleKey': '',
            'callNumber': '',
            'holdType': '',
            'holdRange': '',
            'pickupLibraryID': '',
            'mailServiceID': '',
            'expiresDate': '',
            'suspendStartDate': '',
            'suspendEndDate': '',
            'comment': '',
        },
        'createMySMSEntry': {
            'label': '',
            'phoneNumber': '',
            'countryNameCode': '',
            'optInCheckoutNotices': '',
            'optInHoldPickupNotices': '',
            'optInBillNotices': '',
            'optInManualMessages': '',
            'optInUserAnnouncementMessage': '',
        },
        'createSelfRegisteredPatron': {
            'firstName': '',
            'middleName': '',
            'lastName': '',
            'nameSuffix': '',
            'preferredName': '',
            'socialSecurityNumber': '',
            'birthDate': '',
            'pin': '',
            'street': '',
            'apartment': '',
            'city': '',
            'state': '',
            'postalCode': '',
            'homePhone': '',
            'emailAddress': '',
            'patronLibraryID': '',
        },
        'deleteMyList': {
            'myListID': '',
        },
        'deleteMySMSEntry': {
            'smsKeys': '',
        },
        'enableMyCheckoutHistory': {
            'enable': '',
        },
        'getMyList': {
            'myListID': '',
        },
        'lookupMyAccountInfo': {
            'includePatronInfo ': '',
            'includePatronCirculationInfo': '',
            'includePatronAddressInfo': '',
            'includePatronCheckoutInfo': '',
            'includePatronCheckoutHistoryInfo': '',
            'includePatronHoldInfo': '',
            'includeFeeInfo ': '',
            'includePatronStatusInfo': '',
            'includeUserGroupInfo': '',
            'includeUserSuspensionInfo': '',
            'stationLibraryID': '',
            'includeSMSInfo': '',
            'includePhoto': '',
        },
        'lookupMyList': {
            'myListID': '',
            'includeMyListTitleInfo': '',
        },
        'lookupMyLists': {
            'myListID': '',
        },
        'lookupPatronInfo': {
            'userID': '',
            'alternateID': '',
            'webAuthID': '',
            'includePatronInfo': '',
            'includePatronCirculationInfo': '',
            'includePatronAddressInfo': '',
            'includePatronCheckoutInfo': '',
            'includePatronCheckoutHistoryInfo': '',
            'includePatronHoldInfo': '',
            'includeFeeInfo': '',
            'includePatronStatusInfo': '',
            'includeUserGroupInfo': '',
            'includeUserSuspensionInfo': '',
            'includeSMSInfo': '',
            'includePhoto': '',
        },
        'modifyMyHold': {
            'holdKey': '',
            'expiresDate': '',
            'holdPickupLibraryID': '',
            'mailDeliveryID': '',
        },
        'placeMyHold': {
            'itemID': '',
            'titleKey': '',
            'callNumber': '',
            'holdType': '',
            'holdRange': '',
            'pickupLibraryID': '',
            'mailServiceID': '',
            'expiresDate': '',
            'suspendStartDate': '',
            'suspendEndDate': '',
            'comment': '',
        },
        'renewMyCheckout': {
            'itemID': '',
        },
        'renewMyPrivilege': {
            'postalCode': '',
        },
        'saveMyList': {},
        'suspendMyHold': {
            'holdKey': '',
            'suspendStartDate': '',
            'suspendEndDate': '',
        },
        'unsuspendMyHold': {
            'holdKey': '',
        },
        'updateMySMSEntry': {
            'smsKey': '',
            'label': '',
            'phoneNumber': '',
            'countryNameCode': '',
            'optInCheckoutNotices': '',
            'optInHoldPickupNotices': '',
            'optInBillNotices': '',
            'optInManualMessages': '',
            'optInUserAnnouncementMessages': '',
        },
    },
    'circulation': {
        'browseCallShelf': {
            'itemID': '',
            'browseSize': '',
        },
        'checkin': {
            'itemID': '',
            'checkinDate': '',
            'override': '',
            'ignoreFines': '',
            'offlineTransactionDateTime': '',
            'circSetID': '',
        },
        'checkout': {
            'userID': '',
            'patronKey': '',
            'itemID': '',
            'altDueDate': '',
            'checkinDueDate': '',
            'override': '',
            'offlineTransactionDateTime': '',
            'circSetID': '',            
        },
        'deletePatronPhoto': {
            'userID': '',
            'alternateID': '',
            'userKey': '',
            'webAuthID': '',
        },
        'deselectList': {
            'hitsToDisplay': '',
            'dustyItemFromLibraryID': '',
            'currentLocationID': '',
            'itemTypeID': '',
            'numberOfCheckOuts': '',
            'latestDesectDate': '',
            'startingCallNumberPrefix': '',
            'callNumberClassificationID': '',
            'lastItemID': '',
        },
        'fillHold': {
            'itemID': '',
            'circSetID': '',
        },
        'getDelinquentUsers': {},
        'getUser': {
            'userKey': '',
            'userID': '',
            'altID': '',
            'webAuthID': '',
            'includePhoto': '',
        },
        'holdPullList': {
            'includeExtendedInfo': '',
            'pullListLibraryID': '',
        },
        'lookupItemStatus': {
            'itemID': '',
        },
        'lookupMailDeliveryEstimatesInfo': {
            'userID': '',
            'deliveryServiceID': '',
        },
        'lookupPatronForCko': {
            'userID': '',
            'alternateID': '',
            'webAuthID': '',
            'patronKey': '',
            'includeStatusAlertInfo': '',
            'includeAddressInfo': '',
            'includeExtendedInfo': '',
            'includePhoto': '',
        },
        'lookupSetStatus': {
            'circSetID': '',
        },
        'lookupUserMetadata': {
            'userProfileUsed': '',
            'userCategoryPolicy': '',
            'addressPolicy': '',
            'extendedInfoPolicy': '',
        },
        'markItemDiscard': {
            'itemID': '',
            'currentLocationID': '',
        },
        'markItemInventoried': {
            'itemID': '',
            'transactionDateTime': '',
            'circSetID': '',
        },
        'markItemMissing': {
            'itemID': '',
            'userID': '',
            'override': '',
            'circSetID': '',
        },
        'markItemUsed': {
            'itemID': '',
            'offlineTransactionDateTime': '',
            'circSetID': '',
        },
        'putItemInTransit': {
            'itemID': '',
            'transitSourceLibraryID': '',
            'transitDestinationID': '',
            'transitReasonID': '',
            'override': '',
        },
        'receiveItemFromTransit': {
            'itemID': '',
            'override': '',
        },
        'recordPayments': {
            'billUserID': '',
            'billKey': '',
            'feePayment': '',
            'selfPaid': '',
            'paidAtBillingLibrary': '',
        },
        'renewCheckout': {
            'itemID': '',
            'altDueDate': '',
            'seenByStaff': '',
            'override': '',
            'offlineTransactionDateTime': '',
            'circSetID': '',
        },
        'savePatronPhoto': {
            'userID': '',
            'alternateID': '',
            'userKey': '',
            'webAuthID': '',
            'photo': '',
        },
        'saveUser': {
            'user': ''
            'privilegeExtended': '',
            'zipCodeForPrivilegeExtended': '',
            'privilegeOverride': '',
            'webAuthIDOverride': '',
            'userEditOverride': '',
            'barcodeFormatID': '',
            'barcodePrefix': '',
        },
        'searchPatron': {
            'searchTerm': '',
            'hitsToDisplay': '',
            'sortByIndexID': '',
        },
        'searchPatronPaging': {
            'queryID': '',
            'firstRecordToRetrieve': '',
            'numberOfRecordsToRetrieve': '',
        },
        'sendReceipt': {
            'userID': '',
            'alternateID': '',
            'userKey': '',
            'webAuthID': '',
            'itemID': '',
            'email': '',
            'templateName': '',
        },
        'uploadInventoryTransactions': {
            'date': '',
            'itemID': '',
        },
        'uploadOfflineTransactions': {
            'checkoutInfo': {
                'userID': '',
                'patronKey': '',
                'itemID': '',
                'altDueDate': '',
                'checkinDate': '',
                'override': '',
                'offlineTransactionDateTime': '',
            },
            'checkinInfo': {
                'itemID': '',
                'checkinDate': '',
                'override': '',
                'ignoreFines': '',
                'offlineTransactionDateTime': '',
            }
            'renewCheckoutInfo': {
                'itemID': '',
                'seenByStaff': '',
                'altDueDate': '',
                'override': '',
                'offlineTransactionDateTime': '',
            },
            'offlineCreateUserRequest': {
                'offlineTransactionDateTime': '',
                'user': '',
            },
            'markItemUsedInfo': {
                'itemID': '',
                'offlineTransactionDateTime': '',
            },
            'stationLibraryID': '',
            'userAccessID': '',
        },
    },
    'request': {
        'cancelRequest': {
            'requestKey': '',
        },
        'createRequest': {
            'requestTypeID': '',
            'userID': '',
            'itemID': '',
            'titleKey': '',
            'callNumber': '',
            'serviceLibraryID': '',
            'statusID': '',
            'requestEntry': '',
        },
        'lookupRequest': {
            'requestKey': '',
        },
        'lookupRequests': {
            'userID': '',
            'userAltID': '',
            'requestStatusID': '',
            'serviceLibraryID': '',
            'repliedToRequests': '',
        },
        'lookupRequestTemplate': {
            'requestTypeID': '',
        },
        'updateRequest': {
            'requestID': '',
            'userID': '',
            'itemID': '',
            'titleKey': '',
            'callNumber': '',
            'serviceLibraryID': '',
            'statusID': '',
            'operationType': '',
            'requestEntry': '',
        },
    },
    'reserve': {
        'browseReserve': {
            'browseType': '',
            'browseValue': '',
            'hitsToDisplay': '',
            'reserveDesk': '',
        },
        'browseReservePaging': {
            'browseDirection': '',
            'browseType': '',
            'firstEntryID': '',
            'lastEntryID': '',
            'firstEntryValue': '',
            'lastEntryValue': '',
            'hitsToDisplay': '',
            'reserveDesk': '',
        },
        'listReserve': {
            'hitsToDisplay': '',
            'reserveDesk': '',
            'browseType': '',
            'userPrimaryKey': '',
            'userID': '',
            'courseID': '',
        },
        'listReservePaging': {
            'hitsToDisplay': '',
            'reserveDesk': '',
            'browseType': '',
            'browseDirection': '',
            'firstLineNumber': '',
            'lastLineNumber': '',
            'courseID': '',
            'userPrimaryKey': '',
            'userID': '',
            'listID': '',
        },
        'lookupReserve': {
            'userPrimaryKey': '',
            'userID': '',
            'courseID': '',
            'hitsToDisplay': '',
            'reserveDesk': '',
        },
        'lookupReservePaging': {
            'hitsToDisplay': '',
            'browseDirection': '',
            'firstEntryLineNumber': '',
            'lastEntryLineNumber': '',
            'reserveDesk': '',
            'userPrimaryKey': '',
            'userID': '',
            'listID': '',
        },
    },
    'admin': {
        'getAccessLevelPolicy ': {},
        'getAccessRestrictionPolicy ': {},
        'getBestSellerPolicy': {},
        'getBillPaymentTypePolicy': {},
        'getBillReasonPolicy': {},
        'getCitizenshipPolicy': {},
        'getClearancePolicy': {},
        'getCountryCodePolicy': {},
        'getCreditReasonPolicy': {},
        'getDefaultCountryCodePolicy': {},
        'getGroupResponsibilityPolicy': {},
        'getItemTypePolicy': {},
        'getLanguagePolicy': {},
        'getLibraryGroupPolicy': {},
        'getLibraryPolicy': {},
        'getLocationPolicy': {},
        'getMailServicePolicy': {},
        'getNeedToKnowPolicy': {},
        'getPaymentTypePolicy': {},
        'getPolicy': {
            'policyType': '',
        },
        'getPolicyCacheStamp': {},
        'getRecommendedReadingPolicy': {},
        'getRequestListPolicy': {},
        'getRequestStatusPolicy': {},
        'getRequestTypePolicy': {},
        'getSearchLibraryGroupPolicy': {},
        'getUserLookupPolicy': {},
        'getUserSortPolicy': {},
        'isAccessionEnabled': {},
        'isCASLoginEnabled': {},
        'isCheckoutHistoryEnabled': {},
        'isMailDeliveryEnabled': {},
        'isPatronSelfRegistrationEnabled': {},
        'isRenewPrivilegeCustom': {},
        'isRenewPrivilegeEnabled': {},
        'isRestrictedAccess': {},
        'isSMSEnabled': {},
        'isUserGroupsEnabled': {},
        'lookupAccessLevelPolicyList': {},
        'lookupAccessRestrictionPolicyList': {},
        'lookupBestSellersPolicyList': {},
        'lookupBillPaymentTypePolicyList': {},
        'lookupBillReasonPolicyList': {},
        'lookupCitizenshipPolicyList': {},
        'lookupClearancePolicyList': {},
        'lookupCountryCodePolicyList': {},
        'lookupCreditReasonPolicyList': {},
        'lookupGroupResponsibilityPolicyList': {},
        'lookupILSConfiguration': {},
        'lookupItemTypePolicyList': {},
        'lookupLanguagePolicyList': {},
        'lookupLibraryGroupList': {},
        'lookupLibraryPolicyList': {},
        'lookupLocationPolicyList': {},
        'lookupMailServicePolicyList': {},
        'lookupNativeCurrency': {},
        'lookupNeedToKnowPolicyList': {},
        'lookupPaymentTypePolicyList': {},
        'lookupPolicyList': {
            'policyType': '',
        },
        'lookupRecommendedReadingPolicyList': {},
        'lookupRequestListPolicyList': {},
        'lookupRequestStatusPolicyList': {},
        'lookupRequestTypePolicyList': {},
        'lookupSearchLibraryGroupList': {},
        'lookupUserLookupPolicyList': {},
        'lookupUserSortPolicyList': {},
    },
}

# boolean: '1' 'true', or '0' 'false'.  case-sensitive
# date:  yyyy-mm-dd
# dateTime: yyyy-mm-ddThh:mm:ss

# %% [markdown]
# # This example works #

# %%
arguments = {
    'sessionToken': login_json['sessionToken'],
    'json': True
}

# %%
url = 'https://lalu.sirsi.net/lalu_ilsws/rest/security/lookupSessionInfo'
url = '{}?clientID={}'.format(url, clientID)
for k, v in arguments.items():
    url += '&{}={}'.format(k, v)

# %%
print(url)
r = s.post(url)
r.content

# %% [markdown]
# # This example works too #

# %%
arguments = {
    'sessionToken': login_json['sessionToken'],
    'json': True
}

# %%
service = 'security'
command = 'lookupSessionInfo'

# %%
service = 'standard'
command = 'version'

# %%
url = f'https://lalu.sirsi.net/lalu_ilsws/rest/{service}/{command}?clientID={clientID}'

# %%
response = requests.post(url, params=arguments)

# %%
response.url

# %%
response.content

# %% [markdown]
# # So does this one #

# %%
arguments = {
    'clientID': clientID,
    'sessionToken': login_json['sessionToken'],
    'json': True,
}

# %%
# searchCatalog is the old Advanced Search
arguments.update({
    'term1': 'Man High Castle',
    'searchType1': 'TITLE', # acceptable:  GENERAL, TITLE, AUTHOR, SUBJECT, SERIES, PERTITLE,
    'operator1': 'AND',
    'term2': 'Philip',
    'searchType2': 'AUTHOR',
    'operator2': 'AND',
    'term3': 'Man High Castle',
    'searchType3': 'GENERAL',
    'operator3': 'OR',
    'term4': 'Japan',
    'searchType4': 'SUBJECT',
    'operator4': 'OR',
})
service = 'standard'
command = 'searchCatalog'

# %%
service = 'security'
command = 'lookupSessionInfo'

# %%
arguments.update({
    'titleID': 1098704,
    'includeItemInfo': True,
    'includeCatalogingInfo': True,
    'includeAvailabilityInfo': True,
    'includeMarcHoldings': True,
})

service = 'standard'
command = 'lookupTitleInfo'

# %%
arguments.update({
    'userID': 'GARRETT',
    'includeAccountability': True,
    'includeAllowedCommands': True,
})
service = 'security'
command = 'lookupUserInfo'

# %%
arguments.update({
    'itemID': 31518100550437,
    'browseSize': '15',
})
service = 'circulation'
command = 'browseCallShelf'

# %%
arguments.update({
    'itemID': 31518100550437,
})
service = 'circulation'
command = 'lookupItemStatus'

# %%
arguments.update({
    'browseType': 'COURSE_NAME',
})
service = 'reserve'
command = 'browseReserve'

# %%
# the course reserve lookup fails
arguments.update({
    'userID': 'GARRETT',
    'courseID': 'AAAS 2000',
})
service = 'reserve'
command = 'lookupReserve'

# %%
url = f'https://lalu.sirsi.net/lalu_ilsws/rest/{service}/{command}'
response = requests.post(url, params=arguments)
print(response.url)
print(response.text)

# %% [markdown]
# # this is an old one #

# %%
baseWsURL = 'https://lalu.sirsi.net/lalu_ilsws'
clientID = 'DS_CLIENT'
# catKey = '2805471' # Gay Butler Plater
catKey = '316195' # Korea Journal

my_cross_domain_javascript_method = None
my_cross_domain_data = None

jsonp_options = {'json': 'true',
                'prettyprint': 'false',
                'callback': my_cross_domain_javascript_method,
                'jsonPost': my_cross_domain_data,
                }

options = {"includeAvailabilityInfo": "true",
    "includeCallNumberSummary": "true",
    "includeItemInfo": "true",
    "includeCatalogingInfo": "true",
    "includeOrderInfo": "true",
    "includeOPACInfo": "true",
    "includeBoundTogether": "true",
    "includeMarcHoldings": "true",
    "marcEntryFilter": "ALL",
    "json": "true"}
detail_template = """{baseWsURL}/rest/standard/lookupTitleInfo?clientID={clientID}&titleID={catKey}"""
url_options = "".join('&{}={}'.format(k, v) for k, v in options.items())
detail_template += url_options
detail_url = detail_template.format(baseWsURL=baseWsURL,
                 clientID=clientID,
                 catKey=catKey)
print(detail_url)

# %%
response = requests.post(detail_url)
# response.text

# %%
response.text
